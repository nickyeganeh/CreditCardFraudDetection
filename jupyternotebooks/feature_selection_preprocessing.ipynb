# %%
import warnings
warnings.filterwarnings("ignore")
from imblearn.over_sampling import SMOTE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("../creditcard.csv")
data = data.drop(columns = ["Time"], axis = 1)

# %%
X = data.drop(columns = ['Class'], axis = 1)
y = data.Class

from sklearn.feature_selection import SelectKBest,mutual_info_classif
bestfeatures = SelectKBest(score_func=mutual_info_classif, k=13)
fit = bestfeatures.fit(X,y,)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns) 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature','Score'] 
print(featureScores.nlargest(13,'Score'))
# Out:
#    Feature     Score
# 16     V17  0.008258
# 13     V14  0.008136
# 11     V12  0.007601
# 9      V10  0.007530
# 10     V11  0.006831
# 15     V16  0.006144
# 3       V4  0.004976
# 2       V3  0.004952
# 17     V18  0.004317
# 8       V9  0.004277
# 6       V7  0.003951
# 1       V2  0.003228
# 20     V21  0.002452

# %%
X = X[['Amount', 'V17', 'V14', 'V12', 'V10', 'V11', 'V16', 'V4', 'V3', 'V18', 'V9', 'V7', 'V2']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= .3, random_state = 1)

ss = StandardScaler()
X_train['Amount'] = ss.fit_transform(X_train.Amount.values.reshape(-1,1))

# %%
# Imbalanced Learning
X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %%
X_train
# Out:
#           Amount        V17        V14        V12        V10       V11  \
# 0      -0.295043  -0.337180   0.368247   0.023241  -0.646900 -0.282785
# 1      -0.316497   0.757110   0.959813  -2.785047  -1.221469  1.659649
# 2      -0.344543   0.064331  -0.614734   0.509291  -0.199536  0.644008
# 3      -0.334075   0.148204  -0.318203   0.055726  -0.277888  0.910986
# 4      -0.165199  -0.204127   0.457899   0.705060  -0.109470  0.906279
# ...          ...        ...        ...        ...        ...       ...
# 398009 -0.350135   0.555214 -10.633449  -4.905874  -4.285258  4.382455
# 398010 -0.348799   0.814801 -10.815490  -5.370133  -4.536741  4.126139
# 398011 -0.349250   5.813780  -7.256609  -1.897611  -1.499493  2.600566
# 398012  0.067058 -21.673419  -9.875841 -16.683076 -11.767738  7.071732
# 398013  1.521390   1.734784  -2.357270  -0.640458  -2.208569 -0.482683
#
#               V16        V4         V3       V18        V9         V7  \
# 0       -0.334756 -1.596985  -0.996232 -0.842032 -0.330024   0.288299
# 1        0.471617 -0.429824  -0.318849  1.553497  1.175180   0.815404
# 2        0.668894  0.190985  -1.892041  0.384197  0.314773   0.051364
# 3        0.489917  0.347168  -1.843486  1.153798  0.525494   0.073910
# 4        0.327637  0.822699   1.397751  1.013530 -0.650301  -0.419970
# ...           ...       ...        ...       ...       ...        ...
# 398009  -0.469000  5.878402  -5.764719  0.815651 -3.614634  -1.359766
# 398010  -1.019572  6.092375  -5.496480  0.509716 -3.928938  -1.603959
# 398011   3.062603  4.646278  -4.937644  3.687016 -1.986305   1.082125
# 398012 -13.291792  8.400482 -11.518288 -8.873330 -5.528207 -11.115078
# 398013   0.144528 -0.262158  -2.940520  1.050759 -0.718918   3.914232
#
#               V2
# 0       0.203323
# 1       1.041633
# 2       0.071537
# 3       0.060125
# 4       0.692865
# ...          ...
# 398009  3.277222
# 398010  3.402717
# 398011  3.220715
# 398012  5.754485
# 398013  1.093963
#
# [398014 rows x 13 columns]

# %%
pd.DataFrame(X_train).to_csv("../train-test_data/X_train.csv")
pd.DataFrame(X_test).to_csv("../train-test_data/X_test.csv")
pd.DataFrame(y_train).to_csv("../train-test_data/y_train.csv")
pd.DataFrame(y_test).to_csv("../train-test_data/y_test.csv")
